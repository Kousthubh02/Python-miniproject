# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
covid_data = pd.read_csv("country_wise_latest.csv")

# %%
covid_data
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
chart1 = sns.barplot(x='WHO Region', y='Confirmed', data=covid_data)

# %%
total_confirmed = covid_data['Confirmed'].sum()
total_active = covid_data['Active'].sum()
total_recovered = covid_data['Recovered'].sum()
total_deaths = covid_data['Deaths'].sum()

totals = [total_active, total_recovered, total_deaths]
labels = ['Active', 'Recovered', 'Deaths']
Colors = ['#3274A1', '#3A923A', '#C03D3E']

# %%
chart2 = plt.pie(totals, labels=labels, colors=Colors, autopct='%1.0f%%', startangle=90)
plt.show()

# %%
day_data = pd.read_csv("day_wise.csv")

# %%
day_data
# Out:
#            Date  Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# 0    2020-01-22        555      17         28      510          0           0
# 1    2020-01-23        654      18         30      606         99           1
# 2    2020-01-24        941      26         36      879        287           8
# 3    2020-01-25       1434      42         39     1353        493          16
# 4    2020-01-26       2118      56         52     2010        684          14
# ..          ...        ...     ...        ...      ...        ...         ...
# 183  2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 184  2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 185  2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 186  2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 187  2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
# ...

# %%
sns.violinplot(data=day_data, x="Active",y="Date")
# Out:
# <AxesSubplot:xlabel='Active', ylabel='Date'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# Load some data with dates as the index
df = pd.read_csv("day_wise.csv", index_col=0, parse_dates=[0])

# Create the plot
sns.violinplot(x="variable", y="value", data=pd.melt(df))
plt.xticks(rotation=45)

# Format the y-axis ticks as dates
ax = plt.gca()
ax.yaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.yaxis.set_major_locator(mdates.DayLocator(interval=7))
plt.show()

# %%
filename = 'worldometer_data.csv'
data = pd.read_csv(filename)

# %%
data
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
sns.violinplot(data=data, x="Continent", y="Covid_stage ")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, 'North America'),
#   Text(1, 0, 'South America'),
#   Text(2, 0, 'Asia'),
#   Text(3, 0, 'Europe'),
#   Text(4, 0, 'Africa'),
#   Text(5, 0, 'Australia/Oceania')])

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os.path
filename = 'worldometer_data.csv'

# loading dataset
data=pd.read_csv(filename)

sns.violinplot(data=data, x="Continent", y="Covid_stage ")
#plt.xticks(rotation = 90)

plt.show()
